# %%
# !pip install biopython networkx scipy pandas numpy matplotlib infomap scikit-learn seaborn
# Out:
# Requirement already satisfied: biopython in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.87)
# Requirement already satisfied: networkx in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.6.1)
# Requirement already satisfied: scipy in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.17.1)
# Requirement already satisfied: pandas in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.4.1)
# Requirement already satisfied: matplotlib in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.10.8)
# Requirement already satisfied: infomap in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.12.0)
# Requirement already satisfied: scikit-learn in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.8.0)
# Requirement already satisfied: seaborn in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in C:\Users\amaur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns


from Bio.PDB import PDBParser
from scipy.spatial import cKDTree
from collections import Counter

# %%
nome_proteina = "1A3N"
PDB_FILES = ["data/raw/1A3N/1A3N.pdb"]

# %%
AA_CLASS = {

    # Hidrofóbicos
    "ALA":"hydrophobic",
    "VAL":"hydrophobic",
    "ILE":"hydrophobic",
    "LEU":"hydrophobic",
    "MET":"hydrophobic",
    "PHE":"hydrophobic",
    "TRP":"hydrophobic",
    "PRO":"hydrophobic",

    # Polares
    "SER":"polar",
    "THR":"polar",
    "ASN":"polar",
    "GLN":"polar",
    "TYR":"polar",
    "CYS":"polar",

    # Positivos
    "LYS":"positive",
    "ARG":"positive",
    "HIS":"positive",

    # Negativos
    "ASP":"negative",
    "GLU":"negative",

    # Glicina
    "GLY":"special"
}

# %%
def biochemical_similarity(res1, res2):

    c1 = AA_CLASS.get(res1, "other")
    c2 = AA_CLASS.get(res2, "other")

    if c1 == c2:
        return 1.0

    # atração eletrostática
    if (
        (c1 == "positive" and c2 == "negative")
        or
        (c1 == "negative" and c2 == "positive")
    ):
        return 0.9

    # polar-polar
    if (
        c1 == "polar"
        and
        c2 == "polar"
    ):
        return 0.8

    # hidrofóbico-polar
    if (
        c1 == "hydrophobic"
        and
        c2 == "polar"
    ) or (
        c2 == "hydrophobic"
        and
        c1 == "polar"
    ):
        return 0.3

    return 0.5

# %%
def load_residues(pdb_files):
    parser = PDBParser(QUIET=True)
    residues = []
    for pdb_file in pdb_files:
        structure = parser.get_structure(nome_proteina, pdb_file)
        for model in structure:
            for chain in model:
                for residue in chain:
                    if residue.id[0] != " ":
                        continue
                    if "CA" not in residue:
                        continue
                    ca = residue["CA"]
                    residues.append({
                        "node_id":
                        f"{chain.id}_{residue.id[1]}",
                        "chain":
                        chain.id,
                        "resname":
                        residue.resname,
                        "resid":
                        residue.id[1],
                        "x":
                        float(ca.coord[0]),
                        "y":
                        float(ca.coord[1]),
                        "z":
                        float(ca.coord[2])
                    })
    return pd.DataFrame(residues)

# %%
res_df = load_residues(PDB_FILES)
print("Resíduos:", len(res_df))
res_df.head()
# Out:
# Resíduos: 572
#   node_id chain resname  resid       x          y      z
# 0     A_1     A     VAL      1  10.228  20.761000  6.807
# 1     A_2     A     LEU      2   6.624  21.451000  7.763
# 2     A_3     A     SER      3   4.831  23.237000  4.928
# 3     A_4     A     PRO      4   2.252  25.966000  5.311
# 4     A_5     A     ALA      5  -0.457  23.367001  4.513

# %%
def build_biophysical_graph(residues_df, cutoff, alpha, beta):

    G = nx.Graph()
    
    for row in residues_df.itertuples():
        G.add_node(
            row.node_id,
            chain=row.chain,
            residue=row.resname,
            resid=row.resid
        )
    
    coords = residues_df[
        ["x","y","z"]
    ].values

    node_ids = residues_df["node_id"].values
    residues = residues_df["resname"].values

    tree = cKDTree(coords)
    pairs = tree.query_pairs(r=cutoff)

    for i,j in pairs:
        distance = np.linalg.norm(coords[i]-coords[j])
        spatial_weight = np.exp(-distance/cutoff)
        bio_weight = biochemical_similarity(residues[i],residues[j])
        final_weight = (alpha*spatial_weight + beta*bio_weight)

        G.add_edge(
            node_ids[i],
            node_ids[j],
            distance=distance,
            spatial_weight=spatial_weight,
            bio_weight=bio_weight,
            weight=final_weight
        )

    return G

# %%
# Distância máxima para considerar uma interação (Angstroms)
cutoff=8.0
# alpha e beta definem o Peso da interação
alpha=0.2   # Distância Espacial
beta=0.8    # Similaridade Biofísica

G = build_biophysical_graph(res_df, cutoff, alpha, beta)

print("Nós:", G.number_of_nodes())
print("Arestas:", G.number_of_edges())

# Listar os nós com atributos
nodes_df = pd.DataFrame.from_dict(dict(G.nodes(data=True)), orient="index")
display(nodes_df.head())

# Listar as arestas com atributos
edges_df = pd.DataFrame([
    {"source": u, "target": v, **d}
    for u, v, d in G.edges(data=True)
])
display(edges_df.head())
# Out:
# Nós: 572
# Arestas: 2828
#     chain residue  resid
# A_1     A     VAL      1
# A_2     A     LEU      2
# A_3     A     SER      3
# A_4     A     PRO      4
# A_5     A     ALA      5
#   source target  distance  spatial_weight  bio_weight    weight
# 0    A_1  C_138  7.395008        0.396779         0.3  0.319356
# 1    A_1    A_3  6.228067        0.459090         0.3  0.331818
# 2    A_1    A_2  3.791945        0.622512         1.0  0.924502
# 3    A_1  C_139  7.642722        0.384681         0.5  0.476936
# 4    A_2    A_4  6.746251        0.430296         1.0  0.886059

# %%
degrees = [d for _,d in G.degree()]

print("="*60)
print("Grau médio:", np.mean(degrees))
print("Grau máximo:", np.max(degrees))
print("Densidade:", nx.density(G))
print(f"Conectividade: {nx.is_connected(G)}")
if nx.is_connected(G):
    print(f"Comprimento médio dos caminhos mais curtos: {nx.average_shortest_path_length(G):.2f}")
    print(f"Diâmetro: {nx.diameter(G)}")
print("="*60)
# Out:
# ============================================================
# Grau médio: 9.888111888111888
# Grau máximo: 17
# Densidade: 0.017317183691964777
# Conectividade: True
# Comprimento médio dos caminhos mais curtos: 6.34
# Diâmetro: 13
# ============================================================

# %%
plt.figure(figsize=(8,5))
plt.hist(degrees, bins=50)
plt.xlabel("Grau")
plt.ylabel("Frequência")
plt.title("Distribuição de graus")
plt.show()

# %%
weights = [
    G[u][v]["weight"]
    for u,v in G.edges()
]

plt.figure(figsize=(8,5))

plt.hist(
    weights,
    bins=50
)

plt.xlabel("Peso")
plt.ylabel("Frequência")
plt.title("Distribuição dos pesos")

plt.show()

# %%
chain_counts = Counter(
    nx.get_node_attributes(
        G,
        "chain"
    ).values()
)

pd.DataFrame(
    chain_counts.items(),
    columns=["Chain","Residues"]
).sort_values("Chain")
# Out:
#   Chain  Residues
# 0     A       141
# 1     B       145
# 2     C       141
# 3     D       145

# %%
# Dados dos nós
degrees = dict(G.degree())
print("Degree Centrality: OK")
clustering = nx.clustering(G)
print("Clustering Centrality: OK")
closeness = nx.closeness_centrality(G)
print("Closeness Centrality: OK")
betweenness = nx.betweenness_centrality(G)
print("Betwenness  Centrality: OK")
#eigenvector = nx.eigenvector_centrality(G)
eigenvector = nx.eigenvector_centrality_numpy(G)
print("Eigenvetor Centrality: OK")
page_rank = nx.pagerank(G)
print("Pagerank Centrality: OK")

df_nos = pd.DataFrame({
    "node_id": list(G.nodes()),
    "grau": [degrees[n] for n in G.nodes()],
    "clustering": [clustering[n] for n in G.nodes()],
    "closeness": [closeness[n] for n in G.nodes()],
    "betweenness": [betweenness[n] for n in G.nodes()],
    "eigenvector": [eigenvector[n] for n in G.nodes()],
    "page_rank": [page_rank[n] for n in G.nodes()]
})
# Out:
# Degree Centrality: OK
# Clustering Centrality: OK
# Closeness Centrality: OK
# Betwenness  Centrality: OK
# Eigenvetor Centrality: OK
# Pagerank Centrality: OK

# %%
#df_nos.to_csv("outputs/"+nome_proteina+"_"+str(cutoff)+"_centralidades_nos.csv", index=False)

# %%
print("Estatísticas dos primeiros nós:")
print(df_nos.head().to_string(index=False))
print("="*60)
print("Dados das primeiras arestas:")
for u, v, data in list(G.edges(data=True))[:10]:
    print(f"{u}-{v} {data}")
print("="*60)
# Out:
# Estatísticas dos primeiros nós:
# node_id  grau  clustering  closeness  betweenness  eigenvector  page_rank
#     A_1     4    0.333333   0.160800     0.019191     0.001894   0.000862
#     A_2     8    0.464286   0.164269     0.012465     0.006629   0.001697
#     A_3     6    0.666667   0.154199     0.006600     0.003416   0.000990
#     A_4     6    0.800000   0.146373     0.000270     0.003769   0.001321
#     A_5     7    0.714286   0.151781     0.000465     0.006209   0.001229
# ============================================================
# Dados das primeiras arestas:
# A_1-C_138 {'distance': np.float64(7.395007888239889), 'spatial_weight': np.float64(0.39677893743947185), 'bio_weight': 0.3, 'weight': np.float64(0.3193557874878944)}
# A_1-A_3 {'distance': np.float64(6.228067445099491), 'spatial_weight': np.float64(0.4590902658469972), 'bio_weight': 0.3, 'weight': np.float64(0.33181805316939944)}
# A_1-A_2 {'distance': np.float64(3.7919453682002717), 'spatial_weight': np.float64(0.622511503668646), 'bio_weight': 1.0, 'weight': np.float64(0.9245023007337293)}
# A_1-C_139 {'distance': np.float64(7.642721862463691), 'spatial_weight': np.float64(0.384681241106586), 'bio_weight': 0.5, 'weight': np.float64(0.47693624822131725)}
# A_2-A_4 {'distance': np.float64(6.746251403352721), 'spatial_weight': np.float64(0.43029621927967676), 'bio_weight': 1.0, 'weight': np.float64(0.8860592438559354)}
# A_2-A_7 {'distance': np.float64(6.42175314760017), 'spatial_weight': np.float64(0.44810883381397576), 'bio_weight': 0.5, 'weight': np.float64(0.4896217667627952)}
# A_2-A_128 {'distance': np.float64(6.950798613600403), 'spatial_weight': np.float64(0.4194336933550434), 'bio_weight': 1.0, 'weight': np.float64(0.8838867386710088)}
# A_2-A_6 {'distance': np.float64(5.614776136834046), 'spatial_weight': np.float64(0.49566894876379947), 'bio_weight': 0.5, 'weight': np.float64(0.4991337897527599)}
# A_2-A_127 {'distance': np.float64(6.983741603214702), 'spatial_weight': np.float64(0.4177100696475081), 'bio_weight': 0.5, 'weight': np.float64(0.48354201392950164)}
# A_2-A_3 {'distance': np.float64(3.8002458476397267), 'spatial_weight': np.float64(0.6218659456370044), 'bio_weight': 0.3, 'weight': np.float64(0.36437318912740085)}
# ============================================================

# %%
metricas = ["grau", "clustering", "closeness", "betweenness", "eigenvector", "page_rank"]
# Criar DataFrame com estatísticas descritivas lado a lado
df_stats = pd.DataFrame({m: df_nos[m].describe() for m in metricas})

print("="*60)
print("Estatísticas comparativas das métricas de centralidade")
display(df_stats)
print("="*60)
# Out:
# ============================================================
# Estatísticas comparativas das métricas de centralidade
#              grau  clustering   closeness  betweenness  eigenvector  \
# count  572.000000  572.000000  572.000000   572.000000   572.000000
# mean     9.888112    0.544934    0.159360     0.009373     0.016556
# std      2.617080    0.120368    0.016598     0.010568     0.038428
# min      3.000000    0.300000    0.129010     0.000000     0.000059
# 25%      8.000000    0.461538    0.145099     0.001350     0.000876
# 50%     10.000000    0.514719    0.157235     0.005821     0.002528
# 75%     12.000000    0.619048    0.173306     0.013324     0.013447
# max     17.000000    1.000000    0.196018     0.053210     0.269972
#
#         page_rank
# count  572.000000
# mean     0.001748
# std      0.000420
# min      0.000806
# 25%      0.001457
# 50%      0.001745
# 75%      0.002030
# max      0.002865
# ============================================================

# %%
fig, axes = plt.subplots(2, 3, figsize=(18,10))  # grid 2x3
axes = axes.flatten()

for i, metric in enumerate(metricas):
    axes[i].hist(df_nos[metric], bins=30, color="skyblue", edgecolor="black")
    axes[i].set_title(f"Distribuição de {metric}")
    axes[i].set_xlabel(metric)
    axes[i].set_ylabel("Frequência")
    
plt.suptitle(nome_proteina+"_"+str(cutoff)+" - Métricas de centralidade (todos os vértices)", y=1.02)
plt.tight_layout()
plt.show()

# %%
# Matriz de correlação entre todas as métricas
corr = df_nos[metricas].corr()
display(corr.round(2))

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, fmt=".2f")
plt.title(nome_proteina+"_"+str(cutoff)+" - Correlação entre métricas de centralidade (todos os vértices)")
plt.show()
# Out:
#              grau  clustering  closeness  betweenness  eigenvector  page_rank
# grau         1.00       -0.70       0.43         0.39         0.28       0.86
# clustering  -0.70        1.00      -0.60        -0.61        -0.07      -0.64
# closeness    0.43       -0.60       1.00         0.79        -0.04       0.31
# betweenness  0.39       -0.61       0.79         1.00        -0.01       0.30
# eigenvector  0.28       -0.07      -0.04        -0.01         1.00       0.19
# page_rank    0.86       -0.64       0.31         0.30         0.19       1.00

# %%
fig, axes = plt.subplots(2, 3, figsize=(18,10))  # grid 2x3
axes = axes.flatten()

for i, metric in enumerate(metricas):
    valores = df_nos[metric]
    
    # Histograma
    counts, bins, _ = axes[i].hist(valores, bins=30, color="skyblue", edgecolor="black")
    axes[i].set_title(f"Distribuição de {metric}")
    axes[i].set_xlabel(metric)
    axes[i].set_ylabel("Frequência")
    
    # Escala log-log
    axes[i].set_xscale("log")
    axes[i].set_yscale("log")
    
    # Linha característica (ajuste linear em log-log)
    mask = (counts > 0) & (bins[:-1] > 0)  # filtrar valores válidos
    x = bins[:-1][mask]
    y = counts[mask]
    
    if len(x) > 2:  # só ajusta se houver pontos suficientes
        logx = np.log10(x)
        logy = np.log10(y)
        
        try:
            coef = np.polyfit(logx, logy, 1)  # ajuste linear em log-log
            fitted = 10**(coef[1]) * x**coef[0]
            axes[i].plot(x, fitted, "r--", label=f"linha característica (α={coef[0]:.2f})")
            axes[i].legend(fontsize=8)
        except np.linalg.LinAlgError:
            # Se o ajuste não convergir, apenas pula
            pass


plt.suptitle(nome_proteina+"_"+str(cutoff)+" - Métricas de centralidade (escala log-log)", y=1.02)
plt.tight_layout()
plt.show()

# %%
graus = df_nos["grau"]

# Normalização dos valores de grau
norm = plt.Normalize(vmin=graus.min(), vmax=graus.max())

# Cores baseadas no grau
cores = plt.cm.viridis(norm(graus))

# Tamanho proporcional ao grau
node_sizes = [300 + g*30 for g in graus] 

# Criar dicionário de posições para o layout
pos = {}
for _, linha in res_df.iterrows():
    pos[linha["node_id"]] = (
        linha["x"],
        linha["y"]
    )

plt.figure(figsize=(12,10))
ax = plt.gca()

nx.draw_networkx(
    G,
    pos=pos,
    node_size=node_sizes,
    node_color=cores,
    with_labels=False,
    font_size=7,
    edge_color="lightgray",
    alpha=0.9,
    ax=ax
)

plt.title(nome_proteina+"_"+str(cutoff)+" - Grau dos nós (cor e tamanho)")

# Barra de cores para interpretação
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=norm)
sm.set_array([])
plt.colorbar(
    sm,
    ax=ax,
    label="Grau do nó",
    shrink=0.7,
    aspect=30,
    orientation="horizontal"
)

plt.show()

# %%
from scipy.sparse import csgraph

A = nx.to_numpy_array(G, weight="weight")
print(A.shape)

L = csgraph.laplacian(A, normed=False)
print(L.shape)

L_norm = csgraph.laplacian(A, normed=True)
print(L_norm.shape)
# Out:
# (572, 572)
# (572, 572)
# (572, 572)

# %%
from scipy.sparse.linalg import eigsh

eigenvalues, eigenvectors = eigsh(
    L_norm,
    k=10,
    which="SM"
)

print(eigenvalues)
# Out:
# [6.20796270e-17 1.06322614e-02 1.78453826e-02 2.86500725e-02
#  4.10743265e-02 4.58923183e-02 5.21525434e-02 5.46946309e-02
#  6.41866910e-02 6.91473369e-02]

# %%
# Espectro da Laplaciana
plt.plot(sorted(eigenvalues), 'o-')
plt.title(nome_proteina+"_"+str(cutoff)+" - Espectro da Laplaciana")
plt.xlabel("Índice")
plt.ylabel("Autovalor")
plt.show()

# Subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(14,6))

# --- Histograma dos Autovalores ---
axes[0].hist(eigenvalues, bins=30, color="skyblue", edgecolor="black")
axes[0].set_title(nome_proteina+"_"+str(cutoff)+" - Histograma dos Autovalores")
axes[0].set_xlabel("Autovalor")
axes[0].set_ylabel("Frequência")

# --- Histograma dos Autovalores em escala log-log ---
axes[1].hist(eigenvalues, bins=30, color="salmon", edgecolor="black")
axes[1].set_title(nome_proteina+"_"+str(cutoff)+" - Histograma (log-log)")
axes[1].set_xlabel("Autovalor")
axes[1].set_ylabel("Frequência")
axes[1].set_xscale("log")
axes[1].set_yscale("log")

plt.tight_layout()
plt.show()

# %%
fiedler = eigenvectors[:,1]
plt.figure(figsize=(8,4))

plt.hist(
    fiedler,
    bins=100
)

plt.xlabel("Valor do vetor de Fiedler")
plt.ylabel("Frequência")

plt.title("Distribuição do vetor de Fiedler")

plt.show()

# %%
nodes = list(G.nodes())

spectral_partition = pd.DataFrame({

    "node_id": nodes,

    "spectral_group":
    (fiedler > 0).astype(int)

})

spectral_partition.head()
# Out:
#   node_id  spectral_group
# 0     A_1               0
# 1     A_2               0
# 2     A_3               0
# 3     A_4               0
# 4     A_5               0

# %%
spectral_partition[
    "spectral_group"
].value_counts()
# Out:
# spectral_group
# 1    291
# 0    281
# Name: count, dtype: int64

# %%
nodes = pd.DataFrame({

    "node_id": list(G.nodes()),

    "chain": [
        G.nodes[n]["chain"]
        for n in G.nodes()
    ],

    "spectral_group":
    (fiedler > 0).astype(int)
})

pd.crosstab(
    nodes["chain"],
    nodes["spectral_group"]
)
# Out:
# spectral_group    0    1
# chain
# A               131   10
# B               145    0
# C                 5  136
# D                 0  145

# %%
print("Vetor de Fiedler:")
print(np.round(fiedler,4))

# Histograma da distribuição dos valores do vetor de Fiedler
plt.figure(figsize=(8,6))
plt.hist(fiedler, bins=30, color="skyblue", edgecolor="black")
plt.title(nome_proteina+"_"+str(cutoff)+" - Distribuição do Vetor de Fiedler")
plt.xlabel("Valor do vetor de Fiedler")
plt.ylabel("Frequência")
plt.show()


colors = ['red' if v>0 else 'blue' for v in fiedler]
nx.draw(G,
        pos=pos,
        node_size=node_sizes,
        node_color=colors,
        with_labels=False,
        font_size=7,
        edge_color="lightgray",
        alpha=0.9,
        )
plt.title(nome_proteina+"_"+str(cutoff)+" - Separação pelo vetor de Fiedler")
plt.show()
# Out:
# Vetor de Fiedler:
# [-0.0128 -0.0339 -0.0251 -0.0321 -0.032  -0.0442 -0.0437 -0.0356 -0.0439
#  -0.054  -0.0412 -0.0424 -0.0574 -0.0524 -0.0387 -0.0341 -0.0461 -0.0386
#  -0.0351 -0.0374 -0.0512 -0.0511 -0.0464 -0.0451 -0.052  -0.0502 -0.0462
#  -0.0514 -0.0496 -0.0441 -0.0461 -0.0431 -0.0369 -0.0433 -0.0423 -0.0327
#  -0.0229 -0.0023 -0.0111 -0.0109 -0.0011 -0.0032 -0.0138 -0.0142 -0.0159
#  -0.0263 -0.0278 -0.0337 -0.0263 -0.0274 -0.0289 -0.0357 -0.03   -0.0335
#  -0.0479 -0.0488 -0.0391 -0.0442 -0.0544 -0.0523 -0.0423 -0.0438 -0.0479
#  -0.0417 -0.0393 -0.0395 -0.0321 -0.031  -0.0425 -0.0434 -0.0299 -0.0314
#  -0.0342 -0.022  -0.0257 -0.0337 -0.0227 -0.0165 -0.0279 -0.0288 -0.0144
#  -0.0133 -0.0112 -0.0099 -0.005  -0.0037 -0.0021  0.0007  0.0021  0.0032
#   0.002   0.007   0.001   0.0038 -0.0098 -0.012  -0.0122 -0.0203 -0.0253
#  -0.0299 -0.0382 -0.0335 -0.0376 -0.039  -0.0491 -0.0503 -0.0593 -0.0447
#  -0.0547 -0.0663 -0.0666 -0.0483 -0.058  -0.0555 -0.0393 -0.0383 -0.0636
#  -0.0328 -0.0531 -0.0533 -0.0565 -0.045  -0.05   -0.0439 -0.0499 -0.0439
#  -0.035  -0.0429 -0.0347 -0.0319 -0.0233 -0.0319 -0.0247 -0.0175 -0.0227
#  -0.0158 -0.0104 -0.005   0.0006  0.0025  0.0112 -0.0292 -0.0509 -0.0372
#  -0.0401 -0.0471 -0.0561 -0.0543 -0.0454 -0.0592 -0.0623 -0.0467 -0.0547
#  -0.0576 -0.0534 -0.0419 -0.0418 -0.0529 -0.0376 -0.0563 -0.0623 -0.0559
#  -0.0683 -0.0687 -0.0658 -0.058  -0.0637 -0.0599 -0.0564 -0.048  -0.0563
#  -0.0474 -0.0572 -0.0502 -0.0248 -0.0331 -0.0164 -0.0259 -0.0236 -0.0168
#  -0.0203 -0.0258 -0.0262 -0.0212 -0.0428 -0.0352 -0.0378 -0.0481 -0.0342
#  -0.0362 -0.0552 -0.0366 -0.0516 -0.062  -0.0578 -0.043  -0.0462 -0.0423
#  -0.0475 -0.0652 -0.0725 -0.0518 -0.0599 -0.0679 -0.0683 -0.0568 -0.0545
#  -0.064  -0.0553 -0.0504 -0.0545 -0.0414 -0.0447 -0.0489 -0.0468 -0.0398
#  -0.0449 -0.0464 -0.0295 -0.0343 -0.048  -0.0389 -0.0311 -0.0382 -0.0444
#  -0.0382 -0.0259 -0.03   -0.0308 -0.0274 -0.0229 -0.0253 -0.022  -0.0202
#  -0.0195 -0.018  -0.0141 -0.0197 -0.0118 -0.0309 -0.0195 -0.0241 -0.0417
#  -0.0373 -0.0405 -0.0523 -0.0448 -0.0433 -0.0556 -0.0564 -0.0562 -0.0431
#  -0.0636 -0.0572 -0.0663 -0.059  -0.0449 -0.053  -0.0523 -0.0463 -0.0363
#  -0.0579 -0.0374 -0.0502 -0.0494 -0.0585 -0.0501 -0.0518 -0.0632 -0.0436
#  -0.0497 -0.0478 -0.0519 -0.0469 -0.0451 -0.0379 -0.0573 -0.0482 -0.0301
#  -0.0486 -0.0473 -0.0328 -0.031  -0.0272 -0.0177 -0.0074  0.0154  0.039
#   0.0254  0.0323  0.034   0.0469  0.0456  0.0356  0.044   0.0561  0.043
#   0.0426  0.0575  0.0498  0.0409  0.0371  0.0463  0.0387  0.0352  0.0376
#   0.05    0.0527  0.0466  0.0451  0.0537  0.0502  0.046   0.0512  0.0493
#   0.0435  0.0454  0.0425  0.0337  0.0424  0.0415  0.0322  0.0224  0.002
#   0.0116  0.0137  0.0015  0.0043  0.0193  0.0157  0.017   0.0273  0.0282
#   0.0321  0.0261  0.027   0.0288  0.0355  0.03    0.0336  0.0479  0.049
#   0.043   0.0446  0.0562  0.0528  0.0447  0.0425  0.0485  0.0424  0.0405
#   0.0406  0.0331  0.0322  0.0447  0.0465  0.0338  0.0331  0.036   0.0233
#   0.0274  0.0359  0.0246  0.0181  0.03    0.0313  0.0159  0.0153  0.0134
#   0.0125  0.0077  0.0062  0.0049  0.0025  0.0004 -0.0008 -0.0001 -0.0044
#   0.0008 -0.0032  0.0105  0.0122  0.0126  0.0207  0.0258  0.0298  0.0382
#   0.0339  0.0375  0.0388  0.0489  0.0502  0.0588  0.0445  0.0544  0.0658
#   0.066   0.0479  0.0593  0.0552  0.039   0.0382  0.0634  0.0327  0.0531
#   0.0533  0.0567  0.045   0.0503  0.0431  0.0504  0.0443  0.0391  0.044
#   0.0357  0.033   0.0267  0.0337  0.0262  0.0194  0.0248  0.0179  0.0129
#   0.0077  0.0023  0.0002 -0.0065  0.0295  0.048   0.0378  0.0409  0.0479
#   0.055   0.055   0.0459  0.0595  0.0626  0.047   0.0551  0.058   0.0537
#   0.0422  0.042   0.0532  0.0377  0.0564  0.0589  0.0523  0.0635  0.067
#   0.0659  0.0579  0.0631  0.0598  0.0566  0.0488  0.0561  0.0481  0.0577
#   0.0502  0.0306  0.0344  0.0184  0.0268  0.0233  0.0192  0.0205  0.0273
#   0.0282  0.0225  0.0446  0.0365  0.0389  0.0491  0.0351  0.037   0.0561
#   0.0373  0.0528  0.0632  0.0584  0.0436  0.0472  0.0427  0.0481  0.0659
#   0.0699  0.0522  0.058   0.0681  0.0665  0.0529  0.0545  0.0641  0.0554
#   0.0505  0.0544  0.0414  0.0446  0.0471  0.0466  0.0396  0.0446  0.0458
#   0.0292  0.0339  0.0473  0.038   0.0305  0.0366  0.0434  0.0371  0.0252
#   0.029   0.0295  0.026   0.0218  0.0239  0.0208  0.0191  0.0185  0.0168
#   0.0134  0.016   0.0111  0.0293  0.0186  0.0227  0.0368  0.0358  0.04
#   0.0509  0.0435  0.0384  0.0545  0.0513  0.0552  0.0423  0.0629  0.0563
#   0.0656  0.0584  0.0445  0.0524  0.0518  0.0459  0.0359  0.0573  0.0369
#   0.0494  0.0463  0.0581  0.0493  0.0509  0.0629  0.0429  0.0455  0.0472
#   0.0469  0.0457  0.0439  0.037   0.0525  0.0467  0.0293  0.0459  0.0457
#   0.0315  0.0298  0.024   0.0166  0.0066]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ordena os valores do vetor de Fiedler
sorted_indices = np.argsort(fiedler)
sorted_values = fiedler[sorted_indices]

# Scatterplot 2D
plt.figure(figsize=(10,6))
plt.scatter(range(len(sorted_values)), sorted_values,
            c=["red" if v > 0 else "blue" for v in sorted_values],
            alpha=0.7, edgecolor="black", s=30)

plt.axhline(0, color="black", linestyle="--", linewidth=1)  # linha de separação
plt.title(nome_proteina + " - Scatterplot do vetor de Fiedler")
plt.xlabel("Nós (ordenados)")
plt.ylabel("Valor do vetor de Fiedler")
plt.show()

# %%
from networkx.algorithms.community import louvain_communities
from networkx.algorithms.community import modularity

louvain_comms = louvain_communities(
    G,
    weight="weight",
    seed=42
)

print("Comunidades:", len(louvain_comms))

Q_louvain = modularity(
    G,
    louvain_comms,
    weight="weight"
)

print("Modularidade:", Q_louvain)
# Out:
# Comunidades: 14
# Modularidade: 0.7763812451627713

# %%
louvain_membership = {}

for cid, community in enumerate(louvain_comms):

    for node in community:

        louvain_membership[node] = cid

louvain_df = pd.DataFrame({

    "node_id":
    list(louvain_membership.keys()),

    "louvain":
    list(louvain_membership.values())
})

louvain_df.head()
# Out:
#   node_id  louvain
# 0     A_5        0
# 1    A_17        0
# 2   A_134        0
# 3     A_1        0
# 4   A_124        0

# %%
pd.Series(
    louvain_membership
).value_counts().sort_values(
    ascending=False
).head(20)
# Out:
# 1     61
# 7     60
# 4     52
# 11    52
# 13    50
# 6     49
# 0     38
# 8     36
# 9     35
# 2     34
# 12    29
# 3     28
# 10    25
# 5     23
# Name: count, dtype: int64

# %%
from infomap import Infomap

im = Infomap()

node_to_int = {
    node:i
    for i,node in enumerate(G.nodes())
}

int_to_node = {
    i:node
    for node,i in node_to_int.items()
}

for u,v,data in G.edges(data=True):

    im.add_link(
        node_to_int[u],
        node_to_int[v],
        float(data["weight"])
    )

im.run()

print(
    "Comunidades:",
    im.num_top_modules
)
# Out:
# Comunidades: 3

# %%
infomap_membership = {}

for node in im.nodes:

    infomap_membership[
        int_to_node[node.node_id]
    ] = node.module_id

infomap_df = pd.DataFrame({

    "node_id":
    list(infomap_membership.keys()),

    "infomap":
    list(infomap_membership.values())
})

pd.Series(
    infomap_membership
).value_counts().sort_values(
    ascending=False
).head(20)
# Out:
# 1    290
# 2    162
# 3    120
# Name: count, dtype: int64

# %%
truth = {}

for node in G.nodes():

    chain = G.nodes[node]["chain"]

    if chain in list("AC"):
        truth[node] = "Alpha"

    elif chain in list("BD"):
        truth[node] = "Beta"

# %%
truth_df = pd.DataFrame({

    "node_id":
    list(truth.keys()),

    "truth":
    list(truth.values())
})

truth_df.head()
# Out:
#   node_id  truth
# 0     A_1  Alpha
# 1     A_2  Alpha
# 2     A_3  Alpha
# 3     A_4  Alpha
# 4     A_5  Alpha

# %%
eval_louvain = truth_df.merge(
    louvain_df,
    on="node_id"
)

eval_louvain.head()
# Out:
#   node_id  truth  louvain
# 0     A_1  Alpha        0
# 1     A_2  Alpha        0
# 2     A_3  Alpha        0
# 3     A_4  Alpha        0
# 4     A_5  Alpha        0

# %%
eval_infomap = truth_df.merge(
    infomap_df,
    on="node_id"
)

eval_infomap.head()
# Out:
#   node_id  truth  infomap
# 0     A_1  Alpha        1
# 1     A_2  Alpha        1
# 2     A_3  Alpha        1
# 3     A_4  Alpha        1
# 4     A_5  Alpha        1

# %%
from sklearn.metrics import (
    normalized_mutual_info_score,
    adjusted_rand_score
)

nmi_louvain = normalized_mutual_info_score(

    eval_louvain["truth"],
    eval_louvain["louvain"]
)

ari_louvain = adjusted_rand_score(

    eval_louvain["truth"],
    eval_louvain["louvain"]
)

print("NMI Louvain =", nmi_louvain)
print("ARI Louvain =", ari_louvain)

nmi_infomap = normalized_mutual_info_score(

    eval_infomap["truth"],
    eval_infomap["infomap"]
)

ari_infomap = adjusted_rand_score(

    eval_infomap["truth"],
    eval_infomap["infomap"]
)

print("NMI Infomap =", nmi_infomap)
print("ARI Infomap =", ari_infomap)
# Out:
# NMI Louvain = 0.3579429054234024
# ARI Louvain = 0.13973085002564503
# NMI Infomap = 0.25824775067380223
# ARI Infomap = 0.1714056157795741

# %%
import numpy as np
from sklearn.metrics.cluster import contingency_matrix

def purity_score(
    y_true,
    y_pred
):

    cm = contingency_matrix(
        y_true,
        y_pred
    )

    return np.sum(
        np.max(cm, axis=0)
    ) / np.sum(cm)

purity_louvain = purity_score(

    eval_louvain["truth"],
    eval_louvain["louvain"]
)

print(
    "Purity Louvain =",
    purity_louvain
)

purity_infomap = purity_score(

    eval_infomap["truth"],
    eval_infomap["infomap"]
)

print(
    "Purity Infomap =",
    purity_infomap
)
# Out:
# Purity Louvain = 0.951048951048951
# Purity Infomap = 0.7132867132867133

# %%
louvain_vs_truth = pd.crosstab(
    eval_louvain["truth"],
    eval_louvain["louvain"]
)
louvain_vs_truth.style.background_gradient(
    cmap="Blues"
)
# Out:
# <style type="text/css">
# #T_800d9_row0_col0, #T_800d9_row0_col1, #T_800d9_row0_col2, #T_800d9_row0_col7, #T_800d9_row0_col8, #T_800d9_row0_col9, #T_800d9_row1_col3, #T_800d9_row1_col4, #T_800d9_row1_col5, #T_800d9_row1_col6, #T_800d9_row1_col10, #T_800d9_row1_col11, #T_800d9_row1_col12, #T_800d9_row1_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_800d9_row0_col3, #T_800d9_row0_col4, #T_800d9_row0_col5, #T_800d9_row0_col6, #T_800d9_row0_col10, #T_800d9_row0_col11, #T_800d9_row0_col12, #T_800d9_row0_col13, #T_800d9_row1_col0, #T_800d9_row1_col1, #T_800d9_row1_col2, #T_800d9_row1_col7, #T_800d9_row1_col8, #T_800d9_row1_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_800d9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >louvain</th>
#       <th id="T_800d9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_800d9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_800d9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_800d9_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_800d9_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_800d9_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_800d9_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_800d9_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_800d9_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_800d9_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_800d9_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_800d9_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_800d9_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_800d9_level0_col13" class="col_heading level0 col13" >13</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >truth</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_800d9_level0_row0" class="row_heading level0 row0" >Alpha</th>
#       <td id="T_800d9_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_800d9_row0_col1" class="data row0 col1" >61</td>
#       <td id="T_800d9_row0_col2" class="data row0 col2" >32</td>
#       <td id="T_800d9_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_800d9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_800d9_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_800d9_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_800d9_row0_col7" class="data row0 col7" >59</td>
#       <td id="T_800d9_row0_col8" class="data row0 col8" >34</td>
#       <td id="T_800d9_row0_col9" class="data row0 col9" >35</td>
#       <td id="T_800d9_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_800d9_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_800d9_row0_col12" class="data row0 col12" >13</td>
#       <td id="T_800d9_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_800d9_level0_row1" class="row_heading level0 row1" >Beta</th>
#       <td id="T_800d9_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_800d9_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_800d9_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_800d9_row1_col3" class="data row1 col3" >27</td>
#       <td id="T_800d9_row1_col4" class="data row1 col4" >52</td>
#       <td id="T_800d9_row1_col5" class="data row1 col5" >14</td>
#       <td id="T_800d9_row1_col6" class="data row1 col6" >49</td>
#       <td id="T_800d9_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_800d9_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_800d9_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_800d9_row1_col10" class="data row1 col10" >25</td>
#       <td id="T_800d9_row1_col11" class="data row1 col11" >52</td>
#       <td id="T_800d9_row1_col12" class="data row1 col12" >16</td>
#       <td id="T_800d9_row1_col13" class="data row1 col13" >50</td>
#     </tr>
#   </tbody>
# </table>

# %%
infomap_vs_truth = pd.crosstab(
    eval_infomap["truth"],
    eval_infomap["infomap"]
)

infomap_vs_truth.style.background_gradient(
    cmap="Blues"
)
# Out:
# <style type="text/css">
# #T_1a35d_row0_col0, #T_1a35d_row0_col1, #T_1a35d_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1a35d_row0_col2, #T_1a35d_row1_col0, #T_1a35d_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a35d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >infomap</th>
#       <th id="T_1a35d_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_1a35d_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_1a35d_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >truth</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a35d_level0_row0" class="row_heading level0 row0" >Alpha</th>
#       <td id="T_1a35d_row0_col0" class="data row0 col0" >142</td>
#       <td id="T_1a35d_row0_col1" class="data row0 col1" >21</td>
#       <td id="T_1a35d_row0_col2" class="data row0 col2" >119</td>
#     </tr>
#     <tr>
#       <th id="T_1a35d_level0_row1" class="row_heading level0 row1" >Beta</th>
#       <td id="T_1a35d_row1_col0" class="data row1 col0" >148</td>
#       <td id="T_1a35d_row1_col1" class="data row1 col1" >141</td>
#       <td id="T_1a35d_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
louvain_chain_comm_df = pd.DataFrame({

    "node_id": list(louvain_membership.keys()),

    "community": list(louvain_membership.values()),

    "chain": [
        G.nodes[node]["chain"]
        for node in louvain_membership.keys()
    ]
})

louvain_chain_vs_comm = pd.crosstab(
    louvain_chain_comm_df["chain"],
    louvain_chain_comm_df["community"]
)

louvain_chain_vs_comm.style.background_gradient(
    cmap="Blues"
)
# Out:
# <style type="text/css">
# #T_e9e75_row0_col0, #T_e9e75_row0_col1, #T_e9e75_row0_col2, #T_e9e75_row1_col3, #T_e9e75_row1_col4, #T_e9e75_row1_col5, #T_e9e75_row1_col6, #T_e9e75_row2_col7, #T_e9e75_row2_col8, #T_e9e75_row2_col9, #T_e9e75_row3_col10, #T_e9e75_row3_col11, #T_e9e75_row3_col12, #T_e9e75_row3_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e9e75_row0_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_e9e75_row0_col4, #T_e9e75_row0_col6, #T_e9e75_row0_col7, #T_e9e75_row0_col8, #T_e9e75_row0_col9, #T_e9e75_row0_col10, #T_e9e75_row0_col11, #T_e9e75_row0_col12, #T_e9e75_row0_col13, #T_e9e75_row1_col0, #T_e9e75_row1_col1, #T_e9e75_row1_col2, #T_e9e75_row1_col9, #T_e9e75_row1_col10, #T_e9e75_row1_col11, #T_e9e75_row1_col12, #T_e9e75_row1_col13, #T_e9e75_row2_col0, #T_e9e75_row2_col1, #T_e9e75_row2_col2, #T_e9e75_row2_col3, #T_e9e75_row2_col4, #T_e9e75_row2_col5, #T_e9e75_row2_col6, #T_e9e75_row2_col10, #T_e9e75_row2_col11, #T_e9e75_row2_col13, #T_e9e75_row3_col0, #T_e9e75_row3_col1, #T_e9e75_row3_col3, #T_e9e75_row3_col4, #T_e9e75_row3_col5, #T_e9e75_row3_col6, #T_e9e75_row3_col7, #T_e9e75_row3_col8, #T_e9e75_row3_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e9e75_row0_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_e9e75_row1_col7 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_e9e75_row1_col8 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_e9e75_row2_col12 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_e9e75_row3_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# </style>
# <table id="T_e9e75">
#   <thead>
#     <tr>
#       <th class="index_name level0" >community</th>
#       <th id="T_e9e75_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e9e75_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e9e75_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e9e75_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_e9e75_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_e9e75_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_e9e75_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_e9e75_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_e9e75_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_e9e75_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_e9e75_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_e9e75_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_e9e75_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_e9e75_level0_col13" class="col_heading level0 col13" >13</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >chain</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9e75_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_e9e75_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_e9e75_row0_col1" class="data row0 col1" >61</td>
#       <td id="T_e9e75_row0_col2" class="data row0 col2" >32</td>
#       <td id="T_e9e75_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_e9e75_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e9e75_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_e9e75_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_e9e75_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_e9e75_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_e9e75_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_e9e75_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_e9e75_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_e9e75_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_e9e75_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9e75_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_e9e75_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_e9e75_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_e9e75_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_e9e75_row1_col3" class="data row1 col3" >27</td>
#       <td id="T_e9e75_row1_col4" class="data row1 col4" >52</td>
#       <td id="T_e9e75_row1_col5" class="data row1 col5" >14</td>
#       <td id="T_e9e75_row1_col6" class="data row1 col6" >49</td>
#       <td id="T_e9e75_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_e9e75_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_e9e75_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_e9e75_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_e9e75_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_e9e75_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_e9e75_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9e75_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_e9e75_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_e9e75_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_e9e75_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_e9e75_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_e9e75_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_e9e75_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_e9e75_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_e9e75_row2_col7" class="data row2 col7" >59</td>
#       <td id="T_e9e75_row2_col8" class="data row2 col8" >34</td>
#       <td id="T_e9e75_row2_col9" class="data row2 col9" >35</td>
#       <td id="T_e9e75_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_e9e75_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_e9e75_row2_col12" class="data row2 col12" >13</td>
#       <td id="T_e9e75_row2_col13" class="data row2 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9e75_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_e9e75_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_e9e75_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_e9e75_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_e9e75_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_e9e75_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_e9e75_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_e9e75_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_e9e75_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_e9e75_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_e9e75_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_e9e75_row3_col10" class="data row3 col10" >25</td>
#       <td id="T_e9e75_row3_col11" class="data row3 col11" >52</td>
#       <td id="T_e9e75_row3_col12" class="data row3 col12" >16</td>
#       <td id="T_e9e75_row3_col13" class="data row3 col13" >50</td>
#     </tr>
#   </tbody>
# </table>

# %%
infomap_chain_comm_df = pd.DataFrame({

    "node_id": list(infomap_membership.keys()),

    "community": list(infomap_membership.values()),

    "chain": [
        G.nodes[node]["chain"]
        for node in infomap_membership.keys()
    ]
})

infomap_chain_vs_comm = pd.crosstab(
    infomap_chain_comm_df["chain"],
    infomap_chain_comm_df["community"]
)

infomap_chain_vs_comm.style.background_gradient(
    cmap="Blues"
)
# Out:
# <style type="text/css">
# #T_8d646_row0_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_8d646_row0_col1, #T_8d646_row0_col2, #T_8d646_row1_col1, #T_8d646_row2_col0, #T_8d646_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d646_row1_col0, #T_8d646_row2_col2, #T_8d646_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d646_row1_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8d646_row2_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8d646_row3_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# </style>
# <table id="T_8d646">
#   <thead>
#     <tr>
#       <th class="index_name level0" >community</th>
#       <th id="T_8d646_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_8d646_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_8d646_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >chain</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d646_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_8d646_row0_col0" class="data row0 col0" >141</td>
#       <td id="T_8d646_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8d646_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d646_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_8d646_row1_col0" class="data row1 col0" >144</td>
#       <td id="T_8d646_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8d646_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8d646_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_8d646_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_8d646_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_8d646_row2_col2" class="data row2 col2" >119</td>
#     </tr>
#     <tr>
#       <th id="T_8d646_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_8d646_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_8d646_row3_col1" class="data row3 col1" >141</td>
#       <td id="T_8d646_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
louvain_dominant_comm = louvain_chain_vs_comm.idxmax(axis=1)
louvain_dominant_comm
# Out:
# chain
# A     1
# B     4
# C     7
# D    11
# dtype: int64

# %%
infomap_dominant_comm = infomap_chain_vs_comm.idxmax(axis=1)
infomap_dominant_comm
# Out:
# chain
# A    1
# B    1
# C    3
# D    2
# dtype: int64

# %%
louvain_dominant_count = louvain_chain_vs_comm.max(axis=1)

pd.DataFrame({
    "community": louvain_dominant_comm,
    "residues": louvain_dominant_count
})
# Out:
#        community  residues
# chain
# A              1        61
# B              4        52
# C              7        59
# D             11        52

# %%
infomap_dominant_count = infomap_chain_vs_comm.max(axis=1)

pd.DataFrame({
    "community": infomap_dominant_comm,
    "residues": infomap_dominant_count
})
# Out:
#        community  residues
# chain
# A              1       141
# B              1       144
# C              3       119
# D              2       141

# %%
louvain_chain_purity = (
    louvain_chain_vs_comm.max(axis=1)
    /
    louvain_chain_vs_comm.sum(axis=1)
)

louvain_chain_purity.sort_values(
    ascending=False
)
# Out:
# chain
# A    0.432624
# C    0.418440
# B    0.358621
# D    0.358621
# dtype: float64

# %%
infomap_chain_purity = (
    infomap_chain_vs_comm.max(axis=1)
    /
    infomap_chain_vs_comm.sum(axis=1)
)

infomap_chain_purity.sort_values(
    ascending=False
)
# Out:
# chain
# A    1.000000
# B    0.993103
# D    0.972414
# C    0.843972
# dtype: float64

# %%
plt.figure(figsize=(12,8))

plt.imshow(
    louvain_chain_vs_comm,
    aspect="auto"
)

plt.colorbar()

plt.xticks(
    range(louvain_chain_vs_comm.shape[1]),
    louvain_chain_vs_comm.columns,
    rotation=90
)

plt.yticks(
    range(louvain_chain_vs_comm.shape[0]),
    louvain_chain_vs_comm.index
)

plt.xlabel("Comunidade Louvain")
plt.ylabel("Cadeia")

plt.title(nome_proteina+"_"+str(cutoff)+" - Cadeia × Comunidade")

plt.show()

# %%
plt.figure(figsize=(12,8))

plt.imshow(
    infomap_chain_vs_comm,
    aspect="auto"
)

plt.colorbar()

plt.xticks(
    range(infomap_chain_vs_comm.shape[1]),
    infomap_chain_vs_comm.columns,
    rotation=90
)

plt.yticks(
    range(infomap_chain_vs_comm.shape[0]),
    infomap_chain_vs_comm.index
)

plt.xlabel("Comunidade Infomap")
plt.ylabel("Cadeia")

plt.title(nome_proteina+"_"+str(cutoff)+" - Cadeia × Comunidade")

plt.show()
